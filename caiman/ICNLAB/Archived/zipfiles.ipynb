# %%
import zipfile
from pathlib import Path
from urllib.parse import urlparse, unquote

# files = [
#     "file:///F:/INTRSECT_INVIVO/Analysis/NF170.1L-20251127-FOV1_T3.mat",
#     "file:///F:/INTRSECT_INVIVO/Analysis/NPCNF133.1L-20251029-FOV2_T3.mat",
#     "file:///F:/INTRSECT_INVIVO/Analysis/NPCNF133.1L-20251001-FOV2_T1.mat",
#     "file:///F:/INTRSECT_INVIVO/Analysis/NPCNF133.1L-20250911-FOV3_T1.mat",
#     "file:///F:/INTRSECT_INVIVO/Analysis/NPCNF133.1L-20250911-FOV2_T4.mat",
#     "file:///F:/INTRSECT_INVIVO/Analysis/PC173.2R-20260115-FOV2_T1.mat",
#     "file:///F:/INTRSECT_INVIVO/Analysis/VCNF150.3L-20251120-FOV2_T2.mat",
#     "file:///F:/INTRSECT_INVIVO/Analysis/NPCNF139.1L-20251111-FOV3_T3.mat"
# ]

files = [
    "file:///F:/INTRSECT_INVIVO/Analysis/NF170.1L-20251127-FOV1_T3.pdf",
    "file:///F:/INTRSECT_INVIVO/Analysis/NPCNF133.1L-20251029-FOV2_T3.pdf",
    "file:///F:/INTRSECT_INVIVO/Analysis/NPCNF133.1L-20251001-FOV2_T1.pdf",
    "file:///F:/INTRSECT_INVIVO/Analysis/NPCNF133.1L-20250911-FOV3_T1.pdf",
    "file:///F:/INTRSECT_INVIVO/Analysis/NPCNF133.1L-20250911-FOV2_T4.pdf",
    "file:///F:/INTRSECT_INVIVO/Analysis/PC173.2R-20260115-FOV2_T1.pdf",
    "file:///F:/INTRSECT_INVIVO/Analysis/VCNF150.3L-20251120-FOV2_T2.pdf",
    "file:///F:/INTRSECT_INVIVO/Analysis/NPCNF139.1L-20251111-FOV3_T3.pdf"
]

zip_path = "analysis_files_pdfs.zip"

with zipfile.ZipFile(zip_path, "w", zipfile.ZIP_DEFLATED) as z:
    for uri in files:
        # convert file:/// URI → Windows path
        path = Path(unquote(urlparse(uri).path.lstrip("/")))
        z.write(path, arcname=path.name)

print(f"Saved {zip_path}")
# Out:
# Saved analysis_files_pdfs.zip
